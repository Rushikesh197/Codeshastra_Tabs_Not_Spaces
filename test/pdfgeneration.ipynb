# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet

def generate_pdf(filename):
    # Create a PDF document
    doc = SimpleDocTemplate(filename, pagesize=letter)

    # Set border properties
    border_width = 2
    border_color = (0, 0, 0)  # Black

    # Add border around each page
    doc.leftMargin = doc.rightMargin = border_width
    doc.topMargin = doc.bottomMargin = border_width
    doc.pagesize = (letter[0] - 2 * border_width, letter[1] - 2 * border_width)

    # Set title style
    styles = getSampleStyleSheet()
    title_style = styles["Title"]
    title_style.alignment = 1  # Center alignment

    # Add title
    title_text = "Sample PDF Generated with Python"
    title = Paragraph(title_text, title_style)

    # Build the document content
    content = [title]

    # Add more content here if needed

    # Add content to the document
    doc.build(content)

if __name__ == "__main__":
    filename = "bordered_pages.pdf"
    generate_pdf(filename)
    print(f"PDF generated successfully: {filename}")
# Out:
# PDF generated successfully: bordered_pages.pdf

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib import colors
from reportlab.platypus import SimpleDocTemplate, Paragraph
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.units import inch
from reportlab.pdfgen import canvas

def generate_pdf(filename):
    # Create a PDF document
    doc = SimpleDocTemplate(filename, pagesize=letter)

    # Set title style
    styles = getSampleStyleSheet()
    title_style = styles["Title"]
    title_style.alignment = 1  # Center alignment

    # Add title
    title_text = "Sample PDF Generated with Python"
    title = Paragraph(title_text, title_style)

    # Build the document content
    content = [title]

    # Add more content here if needed

    # Add content to the document
    doc.build(content)

    # Add red line border around each page
    c = canvas.Canvas(filename)
    c.setStrokeColor(colors.red)
    c.rect(0, 0, letter[0], letter[1])
    c.showPage()
    c.save()

if __name__ == "__main__":
    filename = "red_border_pages.pdf"
    generate_pdf(filename)
    print(f"PDF generated successfully: {filename}")
# Out:
# PDF generated successfully: red_border_pages.pdf

# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Image, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch

def generate_pdf(filename):
    # Create a PDF document
    doc = SimpleDocTemplate(filename, pagesize=letter)

    # Set border properties
    border_width = 1
    border_color = "black"

    # Add black borders around each page
    doc.leftMargin = doc.rightMargin = border_width * inch
    doc.topMargin = doc.bottomMargin = border_width * inch

    # Set title style
    styles = getSampleStyleSheet()
    title_style = ParagraphStyle(name='Heading1', fontSize=48, fontName="Helvetica-Bold", underline=True)

    # Add title
    title_text = "Summary"
    title = Paragraph(title_text, title_style)

    # Add paragraph about stocks
    paragraph_text = "This is a summary about stocks..."
    paragraph = Paragraph(paragraph_text, styles["Normal"])

    # Add spacer for vertical spacing
    spacer = Spacer(1, 24)

    # Add image
    image_path = "C:/DRIVE D/Work/Image_reduction/plane.jpg"  # Replace "example.jpg" with the path to your image file
    img = Image(image_path, width=300, height=200)  # Adjust width and height as needed
    img.hAlign = 'CENTER'

    # Add spacer for vertical spacing
    spacer_img = Spacer(1, 12)

    # Add caption
    caption_text = "Fig 1.2"
    caption = Paragraph(caption_text, styles["Normal"])
    caption.hAlign = 'CENTER'

    # Build the document content
    content = [title, spacer, paragraph, spacer_img, img, spacer_img, caption]

    # Add content to the document
    doc.build(content)

if __name__ == "__main__":
    filename = "summary_report.pdf"
    generate_pdf(filename)
    print(f"PDF generated successfully: {filename}")
# Out:
# PDF generated successfully: summary_report.pdf

# %%
from reportlab.lib.pagesizes import letter
from reportlab.platypus import SimpleDocTemplate, Paragraph, Image, Spacer
from reportlab.lib.styles import getSampleStyleSheet, ParagraphStyle
from reportlab.lib.units import inch

def generate_pdf(filename):
    # Create a PDF document
    doc = SimpleDocTemplate(filename, pagesize=letter)

    # Set border properties
    border_width = 1
    border_color = "black"

    # Add black borders around each page
    doc.leftMargin = doc.rightMargin = border_width * inch
    doc.topMargin = doc.bottomMargin = border_width * inch

    # Set title style
    styles = getSampleStyleSheet()
    title_style = ParagraphStyle(name='Heading1', fontSize=48, fontName="Helvetica-Bold", underline=True)

    # Add title
    title_text = "Summary"
    title = Paragraph(title_text, title_style)

    # Add spacer for vertical spacing
    spacer_title = Spacer(1, 24)

    # Add paragraph about stocks
    paragraph_text = "This is a summary about stocks..."
    paragraph = Paragraph(paragraph_text, styles["Normal"])

    # Add spacer for vertical spacing
    spacer_paragraph = Spacer(1, 12)

    # Add image
    image_path = "C:/DRIVE D/Work/Image_reduction/plane.jpg"  # Replace "example.jpg" with the path to your image file
    img = Image(image_path, width=300, height=200)  # Adjust width and height as needed
    img.hAlign = 'CENTER'

    # Add spacer for vertical spacing
    spacer_img = Spacer(1, 12)

    # Add caption
    caption_text = "Fig 1.2"
    caption = Paragraph(caption_text, styles["Normal"])
    caption.hAlign = 'CENTER'

    # Build the document content
    content = [title, spacer_title, paragraph, spacer_paragraph, img, spacer_img, caption]

    # Add content to the document
    doc.build(content)

if __name__ == "__main__":
    filename = "summary_report2.pdf"
    generate_pdf(filename)
    print(f"PDF generated successfully: {filename}")
# Out:
# PDF generated successfully: summary_report2.pdf

# %%
import openai

def generate_portfolio_summary(current_value, invested_value, overall_pnl, daily_pnl, crypto_value, asset_prices, transaction_history, watchlist):
    prompt = f"Portfolio Summary:\n\nCurrent Value: ${current_value}\nInvested Value: ${invested_value}\nOverall Profit/Loss: ${overall_pnl}\nDaily Profit/Loss: ${daily_pnl}\nMoney in Crypto: ${crypto_value}\n\nHigh and Low Prices of Assets:\n"
    for asset, prices in asset_prices.items():
        high_price, low_price = prices
        prompt += f"{asset}: High - ${high_price}, Low - ${low_price}\n"
    prompt += "\nTransaction History:\n"
    for transaction in transaction_history:
        prompt += f"{transaction}\n"
    prompt += "\nWatchlist:\n"
    for asset in watchlist:
        prompt += f"{asset}\n"

    response = openai.Completion.create(
      engine="text-davinci-003",
      prompt=prompt,
      max_tokens=200
    )
    return response.choices[0].text.strip()

# Example usage:
current_value = 15000
invested_value = 12000
overall_pnl = 3000
daily_pnl = 200
crypto_value = 5000
asset_prices = {"Stock A": (50, 45), "Stock B": (70, 65)}
transaction_history = ["Bought 10 shares of Stock A", "Sold 5 shares of Stock B"]
watchlist = ["Stock C", "Crypto D"]

portfolio_summary = generate_portfolio_summary(current_value, invested_value, overall_pnl, daily_pnl, crypto_value, asset_prices, transaction_history, watchlist)
print(portfolio_summary)
# Out:
# ---------------------------------------------------------------------------
# APIRemovedInV1                            Traceback (most recent call last)
# Cell In[3], line 32
#      29 transaction_history = ["Bought 10 shares of Stock A", "Sold 5 shares of Stock B"]
#      30 watchlist = ["Stock C", "Crypto D"]
# ---> 32 portfolio_summary = generate_portfolio_summary(current_value, invested_value, overall_pnl, daily_pnl, crypto_value, asset_prices, transaction_history, watchlist)
#      33 print(portfolio_summary)
#
# Cell In[3], line 15, in generate_portfolio_summary(current_value, invested_value, overall_pnl, daily_pnl, crypto_value, asset_prices, transaction_history, watchlist)
#      12 for asset in watchlist:
#      13     prompt += f"{asset}\n"
# ---> 15 response = openai.Completion.create(
#      16   engine="text-davinci-003",
#      17   prompt=prompt,
#      18   max_tokens=200
#      19 )
#      20 return response.choices[0].text.strip()
#
# ...
